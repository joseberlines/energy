# %% [markdown]
# # check results

# %%
import pandas as pd

# %%
df = pd.read_csv("result-28-10-2022.csv")
df.head()
# Out:
#    Foerdersumme  link_total_sum  \
# 0  1.412.475,59             NaN
# 1  1.408.089,30             NaN
# 2  1.403.419,09             NaN
# 3  1.400.089,91             NaN
# 4  1.395.044,14             NaN
#
#                                         Begünstigter  \
# 0         Stadt Bad Elster – 08645 Bad Elster, Stadt
# 1  Talsperrenbetrieb Sachsen-Anhalt – 38889 Blank...
# 2  Agrargenossenschaft Martinroda e.G. – 98693 Ma...
# 3             Müller Fleisch GmbH – 75217 Birkenfeld
# 4  Landesbetrieb Forst Baden-Würt – 70182 Stuttga...
#
#                                         link_company  \
# 0  /karten/agrarsubventionen_2021-empfaenger1f45d...
# 1  /karten/agrarsubventionen_2021-empfaenger18cc7...
# 2  /karten/agrarsubventionen_2021-empfaenger35574...
# 3  /karten/agrarsubventionen_2021-empfaengerf1591...
# 4  /karten/agrarsubventionen_2021-empfaenger47eff...
#
#                                  Landkreis  \
# 0                            Vogtlandkreis
# ...

# %%
# check some links

# %%
for i  in range(len(df)):
    row = df.iloc[i]
    company = row['Begünstigter']
    link = row['company_url']
    basis_pramie =row['basis_praemie']
    print(i)
    print(company)
    print(link)
    print(basis_pramie)
# Out:
# 0
# Stadt Bad Elster – 08645 Bad Elster, Stadt
# https://proplanta.de/karten/agrarsubventionen_2021-empfaenger1f45d6863e056e84f311520a301f2448.html
# nan
# 1
# Talsperrenbetrieb Sachsen-Anhalt – 38889 Blankenburg (Harz), Stadt
# https://proplanta.de/karten/agrarsubventionen_2021-empfaenger18cc723e6d6e1c4eb10aba68c2da35a0.html
# nan
# 2
# Agrargenossenschaft Martinroda e.G. – 98693 Martinroda
# https://proplanta.de/karten/agrarsubventionen_2021-empfaenger3557437de2220c010679feea0f754b5c.html
# 207.871,69 €
# 3
# Müller Fleisch GmbH – 75217 Birkenfeld
# https://proplanta.de/karten/agrarsubventionen_2021-empfaengerf1591b6051cf8078cf445c1d6fecce52.html
# nan
# 4
# Landesbetrieb Forst Baden-Würt – 70182 Stuttgart, Landeshauptstadt
# https://proplanta.de/karten/agrarsubventionen_2021-empfaenger47eff277da49c9b9bceb331044df13a3.html
# nan
# 5
# Gut Darß GmbH & Co. KG – 18375 Born a. Darß
# https://proplanta.de/karten/agrarsubventionen_2021-empfaenger965a7affb561f7bd76fcf2cabcb7c386.html
# ...
