# %% [markdown]
# # check results

# %%
import pandas as pd

# %%
df = pd.read_csv("companies.csv")
df.head()
# Out:
#    Foerdersumme  link_total_sum  \
# 0  3.695.427,44             NaN
# 1  3.652.411,17             NaN
# 2  3.368.459,38             NaN
# 3  3.336.663,93             NaN
# 4  3.228.789,31             NaN
#
#                                         Begünstigter  \
# 0               Stadt Beelitz – 14547 Beelitz, Stadt
# 1  Landkreis Wittenberg – 06886 Wittenberg, Luthe...
# 2      Landkreis Stendal – 39576 Stendal, Hansestadt
# 3  Thüringer Ministerium für Infrastruktur und La...
# 4  Agraset-Agrargenossenschaft eG Naundorf vertre...
#
#                                         link_company  \
# 0  /karten/agrarsubventionen_2021-empfaenger26072...
# 1  /karten/agrarsubventionen_2021-empfaengerd107d...
# 2  /karten/agrarsubventionen_2021-empfaenger88086...
# 3  /karten/agrarsubventionen_2021-empfaengera7a7c...
# 4  /karten/agrarsubventionen_2021-empfaenger5140f...
#
#                        Landkreis  \
# 0  Potsdam-Mittelmark, Landkreis
# 1          Wittenberg, Landkreis
# 2             Stendal, Landkreis
# 3       Erfurt, Kreisfreie Stadt
# 4       Mittelsachsen, Landkreis
#
#                                        link_location      BundesLand  \
# 0  /karten/potsdam-mittelmark,_landkreis-agrarsub...     Brandenburg
# 1  /karten/wittenberg,_landkreis-agrarsubventione...  Sachsen-Anhalt
# 2  /karten/stendal,_landkreis-agrarsubventionen_2...  Sachsen-Anhalt
# 3  /karten/erfurt,_kreisfreie_stadt-agrarsubventi...       Thüringen
# 4  /karten/mittelsachsen,_landkreis-agrarsubventi...         Sachsen
#
#                                          link_lander  \
# 0  /karten/brandenburg-agrarsubventionen_2021-bun...
# 1  /karten/sachsen-anhalt-agrarsubventionen_2021-...
# 2  /karten/sachsen-anhalt-agrarsubventionen_2021-...
# 3  /karten/thüringen-agrarsubventionen_2021-bunde...
# 4  /karten/sachsen-agrarsubventionen_2021-bundesl...
#
#                                          company_url basis_praemie
# 0  https://proplanta.de/karten/agrarsubventionen_...           NaN
# 1  https://proplanta.de/karten/agrarsubventionen_...           NaN
# 2  https://proplanta.de/karten/agrarsubventionen_...           NaN
# 3  https://proplanta.de/karten/agrarsubventionen_...           NaN
# 4  https://proplanta.de/karten/agrarsubventionen_...  838.059,59 €

# %%
# check some links

# %%
for i  in range(len(df)):
    row = df.iloc[i]
    company = row['Begünstigter']
    link = row['company_url']
    basis_pramie =row['basis_praemie']
    print(i)
    print(company)
    print(link)
    print(basis_pramie)
# Out:
# 0
# Stadt Beelitz – 14547 Beelitz, Stadt
# https://proplanta.de/karten/agrarsubventionen_2021-empfaenger26072b6a7e5ca0a247a1c763946d37d0.html
# nan
# 1
# Landkreis Wittenberg – 06886 Wittenberg, Lutherstadt
# https://proplanta.de/karten/agrarsubventionen_2021-empfaengerd107d5b6515c934a1957db59b0f2a100.html
# nan
# 2
# Landkreis Stendal – 39576 Stendal, Hansestadt
# https://proplanta.de/karten/agrarsubventionen_2021-empfaenger88086a254272d8e798396d1a5a9b4fd3.html
# nan
# 3
# Thüringer Ministerium für Infrastruktur und Landwirtschaft – 99096 Erfurt, Stadt
# https://proplanta.de/karten/agrarsubventionen_2021-empfa